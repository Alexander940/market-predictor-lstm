# %% [markdown]
# # 1. Lectura de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leer data set
ruta = 'C:/Users/pc/Documents/AI/LSTM/data/indicators_results.csv'

df = pd.read_csv(ruta, sep=',')
df
# Out:
#              date         time     open    close     high      low      up  \
# 0      10/30/2022   9:50:00 PM  4371.25  4374.75  4375.75  4370.75   18.59
# 1      10/30/2022  10:00:00 PM  4374.75  4376.00  4378.00  4373.75   13.48
# 2      10/30/2022  10:10:00 PM  4375.75  4373.50  4377.75  4373.00    7.85
# 3      10/30/2022  10:20:00 PM  4373.50  4373.75  4374.25  4372.25    5.17
# 4      10/30/2022  10:30:00 PM  4373.50  4374.50  4375.50  4372.50    5.97
# ...           ...          ...      ...      ...      ...      ...     ...
# 75486  12/06/2024  11:20:00 AM  6172.25  6168.00  6173.00  6165.75  120.88
# 75487  12/06/2024  10:40:00 AM  6179.25  6178.50  6180.25  6176.00   64.64
# 75488  12/06/2024  10:50:00 AM  6178.75  6176.75  6178.75  6175.00   57.71
# 75489  12/06/2024  11:10:00 AM  6177.50  6172.50  6177.75  6170.25   91.41
# 75490  12/06/2024  11:00:00 AM  6176.75  6177.25  6177.75  6172.75   94.40
#
#          down    tema_high     tema_low    tema_up  tema_down  macd_line  \
# 0       10.58  4373.471630  4368.308889  16.383236  13.600468   0.259259
# 1        9.08  4375.168311  4370.332444  15.482362  11.868725   0.559143
# 2       11.63  4376.335240  4371.567881  12.834033  11.482188   0.588293
# 3        6.31  4375.957452  4372.197200   9.921133   9.367452   0.624370
# 4        4.54  4376.076271  4372.714094   8.050711   7.203806   0.705349
# ...       ...          ...          ...        ...        ...        ...
# 75486  148.28  6173.744701  6168.275756  83.008322  87.010704   0.326128
# 75487   69.48  6176.115472  6170.923548  79.604807  84.041170   0.917785
# 75488   62.16  6177.348499  6172.552893  74.332217  78.944217   1.231273
# 75489  114.90  6177.885934  6172.088412  81.904364  93.277749   1.123821
# 75490   96.77  6178.244569  6172.578844  88.411184  97.441075   1.405745
#
#        macd_signal  macd_histogram
# 0         0.051852        0.207407
# 1         0.153310        0.405833
# 2         0.240307        0.347986
# 3         0.317119        0.307250
# 4         0.394765        0.310584
# ...            ...             ...
# 75486     0.404731       -0.078603
# 75487     0.507341        0.410443
# 75488     0.652128        0.579145
# 75489     0.746466        0.377355
# 75490     0.878322        0.527423
#
# [75491 rows x 15 columns]

# %% [markdown]
# # 2. Eliminar columnas y poner datetime como indice

# %%
# Combinar Date y Time en una sola columna DateTime
df['datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'])

# Reorganizar columnas (DateTime primero, eliminar Date y Time originales)
columns = ['datetime', 'open', 'close', 'high', 'low', 'up', 'down', 'tema_high', 'tema_low', 'tema_up', 'tema_down', 
           'macd_line', 'macd_signal', 'macd_histogram']
df = df[columns]

df = df.set_index('datetime')

df.sort_index(inplace=True)

df
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel
plt.show()

# %%
df_g = df[['up', 'down', 'macd_line', 'macd_signal', 'macd_histogram']]
df_g.plot(kind='box', figsize=(20, 10), fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['open', 'close', 'high', 'low', 'up', 'down', 'tema_high', 'tema_low',
#        'tema_up', 'tema_down', 'macd_line', 'macd_signal', 'macd_histogram'],
#       dtype='object')

# %%
def remove_outliers_iqr(df, cols):

    df_wo_outliers = df.copy()

    for col in cols:
        Q1 = df_wo_outliers[col].quantile(0.25)
        Q3 = df_wo_outliers[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df_wo_outliers = df_wo_outliers[(df_wo_outliers[col] >= lower_bound) & (df_wo_outliers[col] <= upper_bound)]

    return df_wo_outliers

# %%
df = remove_outliers_iqr(df, df.columns)
df
# Out:
#                         open    close     high      low     up   down  \
# datetime
# 2022-10-30 21:50:00  4371.25  4374.75  4375.75  4370.75  18.59  10.58
# 2022-10-30 22:00:00  4374.75  4376.00  4378.00  4373.75  13.48   9.08
# 2022-10-30 22:10:00  4375.75  4373.50  4377.75  4373.00   7.85  11.63
# 2022-10-30 22:20:00  4373.50  4373.75  4374.25  4372.25   5.17   6.31
# 2022-10-30 22:30:00  4373.50  4374.50  4375.50  4372.50   5.97   4.54
# ...                      ...      ...      ...      ...    ...    ...
# 2024-12-16 15:20:00  6163.25  6162.25  6163.75  6161.75  13.66  14.86
# 2024-12-16 15:30:00  6162.00  6162.00  6163.00  6160.25  24.81  20.26
# 2024-12-16 16:20:00  6151.00  6149.00  6151.25  6148.25   4.32   8.30
# 2024-12-16 16:30:00  6149.00  6146.75  6149.00  6146.50   3.60   8.10
# 2024-12-16 17:00:00  6149.25  6149.50  6149.75  6148.00   3.55   4.24
#
#                        tema_high     tema_low    tema_up  tema_down  \
# datetime
# 2022-10-30 21:50:00  4373.471630  4368.308889  16.383236  13.600468
# 2022-10-30 22:00:00  4375.168311  4370.332444  15.482362  11.868725
# 2022-10-30 22:10:00  4376.335240  4371.567881  12.834033  11.482188
# 2022-10-30 22:20:00  4375.957452  4372.197200   9.921133   9.367452
# 2022-10-30 22:30:00  4376.076271  4372.714094   8.050711   7.203806
# ...                          ...          ...        ...        ...
# 2024-12-16 15:20:00  6164.285190  6161.143824  17.112495  16.096786
# 2024-12-16 15:30:00  6163.303926  6161.297483   9.262346   6.073437
# 2024-12-16 16:20:00  6155.259572  6152.949267   7.666592   8.271800
# 2024-12-16 16:30:00  6153.548034  6151.210011   9.211579  10.860347
# 2024-12-16 17:00:00  6151.674011  6149.660749  16.387008  18.340250
#
#                      macd_line  macd_signal  macd_histogram
# datetime
# 2022-10-30 21:50:00   0.259259     0.051852        0.207407
# 2022-10-30 22:00:00   0.559143     0.153310        0.405833
# 2022-10-30 22:10:00   0.588293     0.240307        0.347986
# 2022-10-30 22:20:00   0.624370     0.317119        0.307250
# 2022-10-30 22:30:00   0.705349     0.394765        0.310584
# ...                        ...          ...             ...
# 2024-12-16 15:20:00   0.695033     0.603986        0.091047
# 2024-12-16 15:30:00   0.500612     0.611863       -0.111251
# 2024-12-16 16:20:00  -0.290691     0.356631       -0.647322
# 2024-12-16 16:30:00  -0.422038     0.157756       -0.579794
# 2024-12-16 17:00:00  -0.355168    -0.011202       -0.343966
#
# [41550 rows x 13 columns]

# %% [markdown]
# # Analisis explotario

# %%
cols = df.columns

N = df.shape[0]
plots = df[cols][0:N]
plots.index = df.index[0:N]
_ = plots.plot(subplots=True, figsize=(15, 16))

# %% [markdown]
# # Datos faltantes

# %%
print('Cantidad de NaNs:')
for colum in df:
    nans = df[colum].isna().sum()
    print(f'\tColumna {colum}: {nans}')
# Out:
# Cantidad de NaNs:
# 	Columna open: 0
# 	Columna close: 0
# 	Columna high: 0
# 	Columna low: 0
# 	Columna up: 0
# 	Columna down: 0
# 	Columna tema_high: 0
# 	Columna tema_low: 0
# 	Columna tema_up: 0
# 	Columna tema_down: 0
# 	Columna macd_line: 0
# 	Columna macd_signal: 0
# 	Columna macd_histogram: 0

# %% [markdown]
# # Periodicidad de las muestras

# %%
df_time_diffs = df.index.to_series().diff().dt.total_seconds()
print(df_time_diffs.value_counts())
# Out:
# datetime
# 600.0       39832
# 1200.0        319
# 4200.0        238
# 1800.0        145
# 2400.0         91
#             ...
# 207600.0        1
# 200400.0        1
# 12000.0         1
# 55200.0         1
# 24600.0         1
# Name: count, Length: 142, dtype: int64

# %% [markdown]
# Garantizar misma periodicidad entre muestras

# %%
df2 = df.asfreq(freq='10T', method='bfill')

df_time_diffs = df2.index.to_series().diff().dt.total_seconds()
print(df_time_diffs.value_counts())
# Out:
# datetime
# 600.0    112003
# Name: count, dtype: int64
# C:\Users\pc\AppData\Local\Temp\ipykernel_13152\1159721651.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df2 = df.asfreq(freq='10T', method='bfill')

# %% [markdown]
# # Verificar que no se haya cambiado el promedio de los datos

# %%
for colum in df:
    print(f'Promedios original/modificados: {df[colum].mean():.2f} / {df2[colum].mean():.2f}')
# Out:
# Promedios original/modificados: 5073.12 / 5069.04
# Promedios original/modificados: 5073.14 / 5069.38
# Promedios original/modificados: 5074.33 / 5070.83
# Promedios original/modificados: 5071.89 / 5067.54
# Promedios original/modificados: 6.35 / 8.51
# Promedios original/modificados: 6.31 / 8.18
# Promedios original/modificados: 5074.31 / 5070.36
# Promedios original/modificados: 5071.91 / 5067.77
# Promedios original/modificados: 6.00 / 6.05
# Promedios original/modificados: 5.96 / 5.98
# Promedios original/modificados: 0.29 / 0.48
# Promedios original/modificados: 0.30 / 0.50
# Promedios original/modificados: -0.01 / -0.02

# %%
df2.to_csv('../data/indicators_results_10T.csv', sep=';', decimal='.')
